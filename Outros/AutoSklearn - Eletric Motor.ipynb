# %%
# !pip install auto-sklearn
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.1.1 is available.
# You should consider upgrading via the '/home/pedro/meu_projeto/meu_projeto_env/bin/python -m pip install --upgrade pip' command.

# %%
"/home/pedro/meu_projeto/meu_projeto_env/bin/python -m pip install --upgrade pip"
# Out:
# '/home/pedro/meu_projeto/meu_projeto_env/bin/python -m pip install --upgrade pip'

# %%
import autosklearn
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# IncorrectPackageVersionError              Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 import autosklearn
#       2 import pandas as pd
#
# File ~/meu_projeto/meu_projeto_env/lib/python3.8/site-packages/autosklearn/__init__.py:13, in <module>
#      10 requirements = pkg_resources.resource_string('autosklearn', 'requirements.txt')
#      11 requirements = requirements.decode('utf-8')
# ---> 13 dependencies.verify_packages(requirements)
#      15 if os.name != 'posix':
#      16     raise ValueError(
#      17         'Detected unsupported operating system: %s. Please check '
#      18         'the compability information of auto-sklearn: https://automl.github.io'
#      19         '/auto-sklearn/stable/installation.html#windows-osx-compability' %
#      20         sys.platform
#      21     )
#
# ...

# %%
df = pd.read_csv('measures_v2.csv')
# Out:
#         u_q    coolant  stator_winding       u_d  stator_tooth  motor_speed  \
# 0 -0.450682  18.805172       19.086670 -0.350055     18.293219     0.002866
# 1 -0.325737  18.818571       19.092390 -0.305803     18.294807     0.000257
# 2 -0.440864  18.828770       19.089380 -0.372503     18.294094     0.002355
# 3 -0.327026  18.835567       19.083031 -0.316199     18.292542     0.006105
# 4 -0.471150  18.857033       19.082525 -0.332272     18.291428     0.003133
# 5 -0.538973  18.901548       19.077108  0.009147     18.290628     0.009636
# 6 -0.653148  18.941711       19.074583  0.238890     18.292524     0.001337
# 7 -0.758392  18.960861       19.082499  0.395099     18.294041     0.001422
# 8 -0.727128  18.973545       19.085533  0.546623     18.291964     0.000577
# 9 -0.874307  18.987812       19.076025  0.578944     18.287233    -0.001248
#
#         i_d       i_q         pm  stator_yoke    ambient    torque  profile_id
# ...

# %%
df.head(10)
# Out:
#         u_q    coolant  stator_winding       u_d  stator_tooth  motor_speed  \
# 0 -0.450682  18.805172       19.086670 -0.350055     18.293219     0.002866
# 1 -0.325737  18.818571       19.092390 -0.305803     18.294807     0.000257
# 2 -0.440864  18.828770       19.089380 -0.372503     18.294094     0.002355
# 3 -0.327026  18.835567       19.083031 -0.316199     18.292542     0.006105
# 4 -0.471150  18.857033       19.082525 -0.332272     18.291428     0.003133
# 5 -0.538973  18.901548       19.077108  0.009147     18.290628     0.009636
# 6 -0.653148  18.941711       19.074583  0.238890     18.292524     0.001337
# 7 -0.758392  18.960861       19.082499  0.395099     18.294041     0.001422
# 8 -0.727128  18.973545       19.085533  0.546623     18.291964     0.000577
# 9 -0.874307  18.987812       19.076025  0.578944     18.287233    -0.001248
#
#         i_d       i_q         pm  stator_yoke    ambient    torque  profile_id
# ...
